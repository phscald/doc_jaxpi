# %%
import numpy as np
import matplotlib.pyplot as plt

Ly = .014
Lx = .021
y = np.arange(0,0.0141,0.0005)
mu = .1
dpdx = 10/Lx

plt.plot(y, -1/(2*mu)*dpdx*(y**2-Ly*y))
y = Ly/2
print(-1/(2*mu)*dpdx*(y**2-Ly*y))
# Out:
# 0.11666666666666667
